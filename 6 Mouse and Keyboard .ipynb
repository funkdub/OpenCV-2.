# %%
import cv2

img = cv2.imread('../Desktop/test.jpg')
key=0

import cv2
# 定义鼠标事件回调函数
def on_mouse(event, x, y, flags, param):

    # 鼠标左键按下，抬起，双击
    if event == cv2.EVENT_LBUTTONDOWN:
        print('Left button down at ({}, {})'.format(x, y))
    elif event == cv2.EVENT_LBUTTONUP:
        print('Left button up at ({}, {})'.format(x, y))
    elif event == cv2.EVENT_LBUTTONDBLCLK:
        print('Left button double clicked at ({}, {})'.format(x, y))

    # 鼠标右键按下，抬起，双击
    elif event == cv2.EVENT_RBUTTONDOWN:
        print('Right button down at ({}, {})'.format(x, y))
    elif event == cv2.EVENT_RBUTTONUP:
        print('Right button up at ({}, {})'.format(x, y))
    elif event == cv2.EVENT_RBUTTONDBLCLK:
        print('Right button double clicked at ({}, {})'.format(x, y))

    # 鼠标中/滚轮键（如果有的话）按下，抬起，双击
    elif event == cv2.EVENT_MBUTTONDOWN:
        print('Middle button down at ({}, {})'.format(x, y))
    elif event == cv2.EVENT_MBUTTONUP:
        print('Middle button up at ({}, {})'.format(x, y))
    elif event == cv2.EVENT_MBUTTONDBLCLK:
        print('Middle button double clicked at ({}, {})'.format(x, y))

    # 鼠标移动
    elif event == cv2.EVENT_MOUSEMOVE:
        print('Moving at ({}, {})'.format(x, y))

# 为指定的窗口绑定自定义的回调函数
cv2.namedWindow('Honeymoon Island')
cv2.setMouseCallback('Honeymoon Island', on_mouse)


while key != 27:
    cv2.imshow('Honeymoon Island', img)
    key = cv2.waitKey()
    # 如果获取的键值小于256则作为ascii码输出对应字符，否则直接输出值
    msg = '{} is pressed'.format(chr(key) if key < 256 else key)
    print(msg)
# Out:
# Moving at (554, 380)
# Moving at (548, 374)
# Moving at (544, 370)
# Moving at (540, 366)
# Moving at (532, 358)
# Moving at (524, 351)
# Moving at (520, 347)
# Moving at (506, 335)
# Moving at (494, 324)
# Moving at (480, 310)
# Moving at (473, 303)
# Moving at (454, 277)
# Moving at (451, 273)
# Moving at (441, 254)
# Moving at (437, 246)
# Moving at (433, 238)
# Moving at (427, 225)
# Moving at (424, 219)
# Moving at (422, 212)
# Moving at (421, 206)
# Moving at (419, 192)
# Moving at (418, 185)
# Moving at (418, 177)
# Moving at (418, 162)
# Moving at (420, 149)
# Moving at (425, 139)
# Moving at (429, 131)
# Moving at (429, 131)
# Moving at (429, 122)
# Moving at (425, 95)
# Moving at (424, 85)
# Moving at (421, 66)
# Moving at (417, 41)
# Moving at (415, 28)
# Moving at (414, 24)
# Moving at (410, 10)
# Moving at (410, 7)
# Moving at (409, 4)
# Moving at (409, 1)
# Moving at (409, 0)
# Moving at (420, 13)
# Moving at (396, 58)
# Moving at (364, 118)
# Moving at (353, 139)
# Moving at (334, 175)
# Moving at (317, 209)
# Moving at (312, 220)
# Moving at (303, 238)
# Moving at (302, 241)
# Moving at (298, 250)
# Moving at (297, 253)
# Moving at (297, 254)
# Moving at (296, 256)
# Moving at (296, 256)
# Moving at (296, 256)
# Left button down at (296, 256)
# Left button up at (296, 256)
# Moving at (295, 256)
# Moving at (293, 256)
# Moving at (292, 256)
# Moving at (290, 256)
# Moving at (288, 256)
# Moving at (286, 255)
# Moving at (284, 255)
# Moving at (281, 254)
# Moving at (278, 254)
# Moving at (276, 254)
# Moving at (274, 254)
# Moving at (273, 254)
# Moving at (254, 252)
# Moving at (237, 252)
# Moving at (218, 252)
# Moving at (179, 258)
# Moving at (123, 276)
# Moving at (85, 290)
# Moving at (52, 302)
# Moving at (15, 318)
# Moving at (1, 290)
# Moving at (1, 290)
# Moving at (9, 289)
# Moving at (26, 286)
# Moving at (34, 286)
# Moving at (43, 285)
# Moving at (79, 283)
# Moving at (88, 283)
# Moving at (105, 282)
# Moving at (143, 281)
# Moving at (160, 281)
# Moving at (177, 281)
# Moving at (209, 281)
# Moving at (222, 281)
# Moving at (229, 281)
# Moving at (250, 281)
# Moving at (269, 284)
# Moving at (275, 285)
# Moving at (282, 287)
# Moving at (297, 290)
# Moving at (298, 291)
# Moving at (307, 295)
# Moving at (310, 296)
# Moving at (313, 298)
# Moving at (321, 303)
# Moving at (323, 305)
# Moving at (330, 311)
# Moving at (334, 314)
# Moving at (341, 320)
# Moving at (343, 323)
# Moving at (348, 329)
# Moving at (349, 331)
# Moving at (350, 333)
# Moving at (351, 337)
# Moving at (351, 339)
# Moving at (350, 339)
# Moving at (349, 339)
# Moving at (349, 339)
# Moving at (349, 339)
# Moving at (348, 339)
# Left button down at (348, 339)
# Left button up at (348, 339)
# Left button down at (348, 339)
# Left button up at (348, 339)
# Left button double clicked at (348, 339)
# Left button down at (348, 339)
# Left button up at (348, 339)
# Left button down at (348, 339)
# Left button up at (348, 339)
# Moving at (348, 339)
# Moving at (331, 335)
# Moving at (313, 331)
# Moving at (256, 320)
# Moving at (191, 310)
# Moving at (144, 307)
# Moving at (27, 307)
